# %%
from lib import *

# %%
mean = dco("mean_summer_airtemp")
res1 = mean.mean_query()
Image(res1)

# %%
tempclr = dco("AvgTemperatureColorScaled")
date = "2014-06"
res2 = tempclr.temp_color_query(date)
Image(res2)

# %%
diagram = dco("AvgLandTemp")
lat = 53.08
long = 8.80
start_date = "2014-01"
end_date = "2014-06"
res3 = diagram.diagram_query(lat,long,start_date,end_date)
print(res3)
# Out:
# b'2.834646,4.488189,11.10236,20.19685,21.02362,21.29921'

# %%
average = dco("AvgLandTemp")
lat = 53.08
long = 8.80
start_date = "2014-01"
end_date = "2014-06"
res4 = average.avg_query(lat,long,start_date,end_date)
print(res4)
# Out:
# b'13.490813811620077'

# %%
maximum = dco("AvgLandTemp")
lat = 53.08
long = 8.80
start_date = "2014-01"
end_date = "2014-06"
res5 = maximum.max_query(lat,long,start_date,end_date)
print(res5)
# Out:
# b'21.299213'

# %%
minimum = dco("AvgLandTemp")
lat = 53.08
long = 8.80
start_date = "2014-01"
end_date = "2014-06"
res6 = minimum.avg_query(lat,long,start_date,end_date)
print(res6)
# Out:
# b'13.490813811620077'
